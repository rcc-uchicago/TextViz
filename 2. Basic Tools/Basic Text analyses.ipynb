# %%
import nltk

# %%
# directory containing all source texts
data_dir="../corpus"

# %%
import os, glob
os.chdir(data_dir)
docnames = []
documents = []
charcount = 0
bytescount = 0
alldocs = ""

for filename in glob.glob("*.txt"):
    filedata = open(filename, 'r').read()
    docnames.append(filename)
    bytescount = bytescount + len(filedata.encode('utf-8'))
    print(filename + " = " + str(len(filedata)) + " chars & bytes = " + str(len(filedata.encode('utf-8'))))
    documents.append(filedata)
    charcount = charcount + len(filedata)
    alldocs = alldocs + " " + filedata
# Out:
# 1H4_h.txt = 130423 chars & bytes = 131516
# 1H6_h.txt = 116317 chars & bytes = 117376
# 2H4_h.txt = 141574 chars & bytes = 142793
# 2H6_h.txt = 135863 chars & bytes = 137225
# 3H6_h.txt = 129551 chars & bytes = 130819
# Ado_c.txt = 111116 chars & bytes = 111934
# Ant_t.txt = 133668 chars & bytes = 135556
# AWW_c.txt = 121896 chars & bytes = 123376
# AYL_c.txt = 114429 chars & bytes = 115389
# Cor_t.txt = 146443 chars & bytes = 148695
# Cym_t.txt = 147159 chars & bytes = 149389
# Err_c.txt = 76924 chars & bytes = 77554
# H5_h.txt = 141819 chars & bytes = 143051
# H8_h.txt = 128223 chars & bytes = 130089
# Ham_t.txt = 163429 chars & bytes = 165299
# JC_t.txt = 104561 chars & bytes = 105387
# John_t.txt = 112414 chars & bytes = 113303
# Lear_t.txt = 140510 chars & bytes = 142425
# LLL_c.txt = 115391 chars & bytes = 116400
# Lucrece_x.txt = 86177 chars & bytes = 86878
# M4M_c.txt = 116348 chars & bytes = 117538
# Mac_t.txt = 91625 chars & bytes = 92842
# MerchV_c.txt = 112334 chars & bytes = 113294
# MND_c.txt = 88608 chars & bytes = 89320
# Oth_t.txt = 141395 chars & bytes = 143243
# Pericles_x.txt = 97471 chars & bytes = 98656
# PhxTur_x.txt = 2072 chars & bytes = 2098
# R2_h.txt = 120934 chars & bytes = 121927
# R3_h.txt = 156881 chars & bytes = 158253
# Rom_t.txt = 130885 chars & bytes = 132427
# Shr_c.txt = 111364 chars & bytes = 112503
# Sonnets_x.txt = 97204 chars & bytes = 98042
# TGV_c.txt = 91686 chars & bytes = 92534
# Tim_t.txt = 98749 chars & bytes = 100208
# Tit_t.txt = 109892 chars & bytes = 111007
# Tmp_c.txt = 88800 chars & bytes = 90097
# TN_c.txt = 104476 chars & bytes = 105707
# TNK_x.txt = 127691 chars & bytes = 129739
# Tro_c.txt = 142635 chars & bytes = 144392
# VenusAdonis_x.txt = 55527 chars & bytes = 55866
# Wiv_c.txt = 115202 chars & bytes = 116554
# WT_c.txt = 134528 chars & bytes = 136536

# %%
print("bytes " + str(bytescount))
print("\n")
print("chars " + str(charcount))
print("\n")
#print(documents[0])
# Out:
# bytes 4887237
#
#
# chars 4834194

# %%
# create Text object from corpus
from nltk.text import Text
nltk_tokens = nltk.word_tokenize(alldocs)
textList = Text(nltk_tokens)
textList.concordance("forsooth")
# Out:
# Displaying 25 of 25 matches:
#  heat up after I was gone ? He will forsooth have all my prisoners , And when I
# long hast thou to serve , Francis ? Forsooth , five years , and as much as to —
# aked shore at Ravenspurgh , And now forsooth takes on him to reform Some certain
#  upbraid me with my crown Because , forsooth , the King of Scots is crowned . Bu
# h been liberal and free . And yet , forsooth , she is a virgin pure ! — Strumpet
# e crown ? That my master was ? No , forsooth . My master said that he was and th
# ferred in this . Because the King , forsooth , will have it so . Madam , the Kin
#  King , and tell him what miracle . Forsooth , a blind man at Saint Alban ’ s sh
#  and I will help thee . Most true , forsooth , and many time and oft Myself have
#  What color is my gown of ? Black , forsooth , coal-black as jet . Why , then ,
# irrah , what ’ s thy name ? Peter , forsooth . Peter ? What more ? Thump . Thump
#  Duke Humphrey ’ s foes , And you , forsooth , had the good duke to keep . ’ Tis
# chets that he speaks ! Note notes , forsooth , and nothing . Now , divine air !
#  , get thee gone . Farewell . Yes , forsooth . I wish you joy o ’ th ’ worm . Gi
#  gown of a big heart . I am going , forsooth . The business is for Helen to come
# rns and elegies on brambles , all , forsooth , deifying the name of Rosalind . I
# ves ; but thou wilt frame Thyself , forsooth , hereafter theirs , so far As thou
#  dead man . This pernicious slave , Forsooth , took on him as a conjurer , And ,
# honest , And live a subject ? Nay , forsooth . My friends , They that must weigh
# n my conscience , put unwittingly — Forsooth , an inventory , thus importing The
# m a Fool . Thou art nothing . Yes , forsooth , I will hold my tongue . So your f
# int . Gardon ! Remuneration ! And I forsooth in love ! I that have been love ’ s
# arthest steep of India , But that , forsooth , the bouncing Amazon , Your buskin
# h within his soul ) And tender me , forsooth , affection , But by your setting o
# , her tall personage , Her height , forsooth , she hath prevailed with him . And

# %%
import matplotlib
textList.dispersion_plot(["forsooth","king"])

# %%
# lexical diversity scores
ld_tuple = []

def ldiv(text):
    return len(set(text)) / len(text)

xcount = 1
for doc in documents:
    nltk_tokenz = nltk.word_tokenize(doc)
    textListz = Text(nltk_tokenz)
    ld = ldiv(textListz)
    ld_tuple.append([docnames[xcount-1], ld])
    xcount = xcount + 1
    
ld_tuple

#display tuple sorted by lexical diversity score
#sorted(ld_tuple, key=lambda x: x[1], reverse=True)
# Out:
# [['PhxTur_x.txt', 0.555045871559633],
#  ['VenusAdonis_x.txt', 0.2380751371886872],
#  ['Lucrece_x.txt', 0.21566763587564303],
#  ['Mac_t.txt', 0.17710931768158475],
#  ['Tmp_c.txt', 0.1702547896504049],
#  ['1H6_h.txt', 0.1665867880821152],
#  ['MND_c.txt', 0.16509291813159216],
#  ['Sonnets_x.txt', 0.1631323697223279],
#  ['Tim_t.txt', 0.15992111514499574],
#  ['Pericles_x.txt', 0.15980365421325335],
#  ['John_t.txt', 0.15902888101348323],
#  ['H5_h.txt', 0.1586870840602184],
#  ['Err_c.txt', 0.15568355073691342],
#  ['LLL_c.txt', 0.15546508948459944],
#  ['R2_h.txt', 0.15259518200471162],
#  ['Tit_t.txt', 0.1510528047376213],
#  ['2H6_h.txt', 0.1455807619490484],
#  ['TNK_x.txt', 0.14395302264010046],
#  ['Lear_t.txt', 0.1435659109464297],
#  ['Ant_t.txt', 0.14285714285714285],
#  ['Tro_c.txt', 0.14284382863711206],
#  ['TGV_c.txt', 0.14136975833412935],
#  ['1H4_h.txt', 0.1410816716744059],
#  ['2H4_h.txt', 0.13925649853131614],
#  ['MerchV_c.txt', 0.13919153639665247],
#  ['M4M_c.txt', 0.13731751824817517],
#  ['WT_c.txt', 0.13731372485081683],
#  ['Cym_t.txt', 0.13730531224776538],
#  ['Ham_t.txt', 0.13709328721219327],
#  ['TN_c.txt', 0.13708620124549328],
#  ['Shr_c.txt', 0.13666187832433901],
#  ['AWW_c.txt', 0.1363062380488509],
#  ['H8_h.txt', 0.13584146045187936],
#  ['JC_t.txt', 0.13509263980962094],
#  ['AYL_c.txt', 0.1348435814455232],
#  ['3H6_h.txt', 0.13398362654589793],
#  ['Rom_t.txt', 0.13366106423968643],
#  ['Cor_t.txt', 0.13127168502036507],
#  ['Wiv_c.txt', 0.13084216397099832],
#  ['R3_h.txt', 0.12799215550556614],
#  ['Ado_c.txt', 0.12692232055063912],
#  ['Oth_t.txt', 0.1257223656707242]]

# %%
# collocations (2 words in sequence occurring more than once) from all documents
xcount = 1
for doc in documents:
    nltk_tokenz = nltk.word_tokenize(doc)
    textListz = Text(nltk_tokenz)
    #textListz.collocations()
    print("text" + str(xcount))
    print(textListz.collocations())
    print("----")
    xcount = xcount + 1
# Out:
# text1
# Sir John; thou art; thou hast; Thou art; thousand pound; Owen
# Glendower; set forth; Sir Walter; Jack Falstaff; Good morrow; Sir
# Michael; hast thou; thou wilt; Harry Percy; Art thou; Dost thou;
# plague upon; true prince; heir apparent; Walter Blunt
# None
# ----
# text2
# thou wilt; Lord Talbot; thou shalt; white rose; thou canst; thou art;
# Thou art; Saint George; King Henry; thy father; Lord Protector; ere
# long; Sir William; Master Vernon; Thomas Gargrave; Wilt thou; red
# rose; tawny coats; thy foes; gracious sovereign
# None
# ----
# text3
# Sir John; Master Shallow; John Falstaff; thou art; Robert Shallow; God
# save; Master Silence; Master Robert; Thou art; Good morrow; Master
# Gower; Holy Land; Well said; Chief Justice; Thou hast; thou wert;
# honest man; Harry Monmouth; William cook; five-and-twenty thousand
# None
# ----
# text4
# Duke Humphrey; Jack Cade; thou art; Lord Protector; Saint Albans; Sir
# John; thou hast; thou shalt; rightful heir; Lord Saye; Saint Alban;
# King Henry; God save; ten thousand; Lord Cardinal; art thou; gracious
# lord; Dame Eleanor; royal person; thousand crowns
# None
# ----
# text5
# Lady Bona; King Henry; thou shalt; thou hast; thou art; Lord Hastings;
# King Edward; gracious lord; Saint Albans; God forbid; wilt thou; Sir
# John; many hours; master mayor; Saint George; thou wast; thousand men;
# King Lewis; Brave warriors; Thou art
# None
# ----
# text6
# Signior Benedick; chamber window; Good morrow; Count Claudio; pray
# thee; thou art; Signior Leonato; Dost thou; savage bull; thou wilt;
# Thou hast; old man; thou dost; God help; thousand ducats; Sweet
# prince; Scotch jig; Lady Beatrice; Master constable; come hither
# None
# ----
# text7
# Mark Antony; thou hast; FIRST GUARD; Thou hast; Sextus Pompeius; thy
# hand; give thee; gainst Pompey; Thou art; Good morrow; Come hither;
# Dost thou; Hast thou; Get thee; Marcus Crassus; thou shouldst; thy
# cheek; SECOND GUARD; Thou shalt; Wilt thou
# None
# ----
# text8
# Count Rossillion; thou art; good lord; Monsieur Parolles; Saint
# Jaques; Captain Dumaine; good lady; God save; Among nine; thou canst;
# take heed; mine eye; nine bad; withered pear; Ere twice; great deal;
# young lords; shall find; God send; thou hast
# None
# ----
# text9
# Sir Rowland; thou art; Thou art; Thou hast; married tomorrow; youngest
# son; seventh cause; lie direct; pretty ring; cast away; Wilt thou;
# thou canst; every day; thou shalt; hey ding; Sweet lovers; Sir Oliver;
# well cut; ring time; good manners
# None
# ----
# text10
# Titus Lartius; Caius Martius; thou hast; Thou art; Thou hast; thou
# None
# ----
# text36
# Thou liest; thou art; widow Dido; Thou shalt; Hast thou; four legs;
# thou didst; Dost thou; Wilt thou; Thou dost; Thou hast; three hours;
# thou cam; mine enemies; harmless fairy; thou canst; mine eyes; bring
# thee; thou wast; thou hast
# None
# ----
# text37
# Sir Toby; Sir Topas; thou art; Sir Andrew; yellow stockings; thou
# hast; dost thou; Count Orsino; Master Parson; Thou shalt; raineth
# every; every day; Lady Olivia; see thee; mine eyes; achieve greatness;
# Mistress Mary; bloody coxcomb; mine honor; young gentleman
# None
# ----
# text38
# thou art; Thou art; one another; never saw; dead lords; could wish;
# must needs; shall never; take heed; would fain; convent naught; young
# handsome; mine eyes; Hey nonny; thou hast; Thou shalt; two hours; fair
# hand; thou canst; Pretty soul
# None
# ----
# text39
# sweet queen; Good morrow; Lord Aeneas; Thou art; thou art; Good night;
# must needs; Queen Hecuba; tell thee; art thou; Prince Troilus; brother
# Troilus; thou hast; Art thou; Lady Cressid; Lord Pandarus; procure
# safe-conduct; good night; depend upon; addle egg
# None
# ----
# text40
# thou wilt; heavenly moisture; Art thou; mine ear; must confess;
# thousand ways; nothing else; twenty times; silver doves; take
# advantage; one minute; thou shalt; tender spring; sweet embrace; thy
# lips; thy father; dost thou; thou dost; mine eyes; Thou art
# None
# ----
# text41
# Sir John; Master Brook; Anne Page; Mistress Ford; mine Host; Mistress
# Anne; Mistress Page; Master Slender; Master Fenton; Sir Hugh; Master
# Page; Master Doctor; Doctor Caius; Master Ford; John Falstaff; old
# woman; Jack Rugby; God bless; Thou art; vill kill
# None
# ----
# text42
# thou art; tall fellow; gentleman born; look upon; old man; mine honor;
# good sir; thou hast; Prince Florizell; wide gap; good deed; good
# Camillo; young prince; thy hand; thou dost; old tale; next way; thy
# hands; thy mother; hath made
# None
# ----

# %%
# word lengths > 18 from all documents
wl18 = []
for doc in documents:
    nltk_tokenz = nltk.word_tokenize(doc)
    for token in nltk_tokenz:
        if len(token) > 18:
            wl18.append(token + " " + str(len(token))) 
print(wl18)
# Out:
# ['waiting-gentlewoman 19', 'dishonorable-ragged 19', 'that-way-accomplished 21', 'always-wind-obeying 19', 'historical-pastoral 19', 'tragical-historical 19', 'tragical-comical-historical-pastoral 36', 'honorable-dangerous 19', 'one-trunk-inheriting 20', 'honorificabilitudinitatibus 27', 'wholesome-profitable 20', 'death-counterfeiting 20', 'ten-times-barred-up 19', 'six-or-seven-times-honored 26', 'waiting-gentlewoman 19']

# %%
# Use RegEx to find all words beginning with "c" and ending with "le" or "um"
import re
reoutput = []
for doc in documents:
    nltk_tokenz = nltk.word_tokenize(doc)
    for token in nltk_tokenz:
        if re.search("^c.*(le|um)$", token) and token not in reoutput:
            reoutput.append(token) 
print(reoutput)
# Out:
# ['castle', 'candle', 'camomile', 'cantle', 'chronicle', 'contemptible', 'circle', 'commendable', 'capable', 'cuttle', 'cradle', 'couple', 'cripple', 'crocodile', 'culpable', 'caudle', 'cable', 'cinable', 'constable', 'charitable', 'corrigible', 'comfortable', 'credible', 'cattle', 'changeable', 'carbuncle', 'cockle', 'clotpole', 'condole', 'corruptible', 'cuppele', 'cum', 'conformable', 'cobble', 'crumble', 'colorable', 'compile', 'carry-tale', 'concupiscible', 'conscionable', 'captum', 'consum', 'comptible', 'cold-pale']
